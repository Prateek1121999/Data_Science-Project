# %%
import pandas as pd

# %%
Data = pd.read_csv(r"C:\Users\prate\Downloads\DiwaliSalesData.csv",encoding='unicode_escape',parse_dates=True)

# %%
Data.head(15)
# Out:
#     User_ID  Cust_name Product_ID Gender Age Group  Age  Married  \
# 0   1002903  Sanskriti  P00125942      F     26-35   28        0
# 1   1000732     Kartik  P00110942      F     26-35   35        1
# 2   1001990      Bindu  P00118542      F     26-35   35        1
# 3   1001425     Sudevi  P00237842      M      0-17   16        0
# 4   1000588       Joni  P00057942      M     26-35   28        1
# 5   1000588       Joni  P00057942      M     26-35   28        1
# 6   1001132       Balk  P00018042      F     18-25   25        1
# 7   1002092   Shivangi  P00273442      F       55+   61        0
# 8   1003224     Kushal  P00205642      M     26-35   35        0
# 9   1003650      Ginny  P00031142      F     26-35   26        1
# 10  1003829   Harshita  P00200842      M     26-35   34        0
# 11  1000214   Kargatis  P00119142      F     18-25   20        0
# 12  1004035     Elijah  P00080342      F     18-25   20        1
# ...

# %%
Data.shape
# Out:
# (11251, 15)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
Data.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
Data.isna().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
Data.drop(['unnamed1','Status'],axis=1,inplace=True)

# %%
Data['Amount'].median()
# Out:
# 8109.0

# %%
Data['Amount'].mode()
# Out:
# 0    7907.0
# Name: Amount, dtype: float64

# %%
Data.duplicated('Amount').sum()
# Out:
# 4666

# %%
Data['Amount'].fillna(7907,inplace=True)

# %%
# drop null values
# Data.dropna(inplace=True)

# %%
# change data type
Data['Amount'] = Data['Amount'].astype('int')
Data['Amount'].dtypes
# Out:
# dtype('int32')

# %%
Data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#rename column
Data.rename(columns= {'Marital_Status':'Married'},inplace=True)

# %%
# for looking duplicated data
Data[Data['Amount'].duplicated()].head(10)
# Out:
#      User_ID Cust_name Product_ID Gender Age Group  Age  Married  \
# 5    1000588      Joni  P00057942      M     26-35   28        1
# 14   1003858      Cano  P00293742      M     46-50   46        1
# 16   1005447       Amy  P00275642      F     46-50   48        1
# 19   1001883   Praneet  P00029842      M     51-55   54        1
# 71   1003751    Victor  P00129542      M     36-45   38        1
# 81   1000154     Shami  P00306042      F     51-55   53        1
# 84   1001284   O'Brian  P00157142      M     46-50   50        0
# 103  1004079    Fisher  P00284742      F     36-45   44        1
# 105  1004335     Aryan  P00075542      F     36-45   38        0
# 107  1003311     Neola  P00142742      F     26-35   26        1
#
#                 State      Zone       Occupation  Product_Category  Orders  \
# 5    Himachal Pradesh  Northern  Food Processing              Auto       1
# 14     Madhya Pradesh   Central      Hospitality              Auto       3
# ...

# %%
Data.describe()
# Out:
#             User_ID           Age       Married        Orders        Amount
# count  1.125100e+04  11251.000000  11251.000000  11251.000000  11251.000000
# mean   1.003004e+06     35.421207      0.420318      2.489290   9451.960981
# std    1.716125e+03     12.754122      0.493632      1.115047   5219.813316
# min    1.000001e+06     12.000000      0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000      0.000000      1.500000   5443.500000
# 50%    1.003065e+06     33.000000      0.000000      2.000000   8108.000000
# 75%    1.004430e+06     43.000000      1.000000      3.000000  12671.000000
# max    1.006040e+06     92.000000      1.000000      4.000000  23952.000000

# %%
Data.to_excel('DiwaliSales.xlsx')
